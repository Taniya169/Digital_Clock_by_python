# %%
import time
import datetime as dt
import turtle


# create a turtle to display time
t = turtle.Turtle()

# create a turtle to create rectangle box
t1 = turtle.Turtle()

# create screen
s = turtle.Screen()

# set background color of the screen
s.bgcolor("black")

# obtain current hour, minute and second
# from the system
sec = dt.datetime.now().second
min = dt.datetime.now().minute
hr = dt.datetime.now().hour
t1.pensize(3)
t1.color('white')
t1.penup()

# set the position of turtle
t1.goto(-20, 0)
t1.pendown()

# create rectangular box
for i in range(2):
	t1.forward(200)
	t1.left(90)
	t1.forward(70)
	t1.left(90)

# hide the turtle
t1.hideturtle()

while True:
	t.hideturtle()
	t.clear()
	# display the time
	t.write(str(hr).zfill(2)
			+ ":"+str(min).zfill(2)+":"
			+ str(sec).zfill(2),
			font=("Arial Narrow", 35, "bold"))
	time.sleep(1)
	sec += 1

	if sec == 60:
		sec = 0
		min += 1

	if min == 60:
		min = 0
		hr += 1

	if hr == 13:
		hr = 1
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 43
#      41 while True:
#      42 	t.hideturtle()
# ---> 43 	t.clear()
#      44 	# display the time
#      45 	t.write(str(hr).zfill(2)
#      46 			+ ":"+str(min).zfill(2)+":"
#      47 			+ str(sec).zfill(2),
#      48 			font=("Arial Narrow", 35, "bold"))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:2650, in RawTurtle.clear(self)
#    2638 def clear(self):
#    2639     """Delete the turtle's drawings from the screen. Do not move turtle.
#    2640
#    2641     No arguments.
#    (...)
#    2648     >>> turtle.clear()
#    2649     """
# -> 2650     self._clear()
#    2651     self._update()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:2628, in RawTurtle._clear(self)
#    2626 self._fillitem = self._fillpath = None
#    2627 for item in self.items:
# -> 2628     self.screen._delete(item)
#    2629 self.currentLineItem = self.screen._createline()
#    2630 self.currentLine = []
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:551, in TurtleScreenBase._delete(self, item)
#     547 def _delete(self, item):
#     548     """Delete graphics item from canvas.
#     549     If item is"all" delete all graphics items.
#     550     """
# --> 551     self.cv.delete(item)
#
# File <string>:1, in delete(self, *args, **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:2897, in Canvas.delete(self, *args)
#    2895 def delete(self, *args):
#    2896     """Delete items identified by all tag or ids contained in ARGS."""
# -> 2897     self.tk.call((self._w, 'delete') + args)
#
# TclError: invalid command name ".!canvas"

# %%
import time
import datetime as dt
import turtle


#create turtle to display time
t =  turtle.Turtle()
#create turtle to create rectangular box
t1 = turtle.Turtle()
#create screen
s =  turtle.Screen()
#set background color of the screen
s.bgcolor("yellow")
# obtain current hour, minute and second
# from the system
sec=dt.datetime.now().second
min=dt.datetime.now().minute
hr=dt.datetime.now().hour
t1.pensize(3)
t1.color("black")
t1.penup()

#set the position of turtle
t1.goto(-20,0)
t1.pendown()
#create rectangular box
for i in range(2):
    t1.forward(200)
    t1.left(90)
    t1.forward(70)
    t1.left(90)
#hide the turtle
    t1.hideturtle()
while True:
    t.hideturtle()
    t.clear()
    #display the time
    t.write (str(hr).zfill(2) + ":" + str(min).zfill(2) + ":" + str(sec).zfill(2),
              font=("Arial Narrow",35,"bold"))
    time.sleep(1)

    sec+=1
    if sec==60:
          sec=0
          min+=1
    if min==60:
         min=0
         hr+=1
    if hr==13:
        hr=1
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 36
#      34 while True:
#      35     t.hideturtle()
# ---> 36     t.clear()
#      37     #display the time
#      38     t.write (str(hr).zfill(2) + ":" + str(min).zfill(2) + ":" + str(sec).zfill(2),
#      39               font=("Arial Narrow",35,"bold"))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:2650, in RawTurtle.clear(self)
#    2638 def clear(self):
#    2639     """Delete the turtle's drawings from the screen. Do not move turtle.
#    2640
#    2641     No arguments.
#    (...)
#    2648     >>> turtle.clear()
#    2649     """
# -> 2650     self._clear()
#    2651     self._update()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:2628, in RawTurtle._clear(self)
#    2626 self._fillitem = self._fillpath = None
#    2627 for item in self.items:
# -> 2628     self.screen._delete(item)
#    2629 self.currentLineItem = self.screen._createline()
#    2630 self.currentLine = []
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\turtle.py:551, in TurtleScreenBase._delete(self, item)
#     547 def _delete(self, item):
#     548     """Delete graphics item from canvas.
#     549     If item is"all" delete all graphics items.
#     550     """
# --> 551     self.cv.delete(item)
#
# File <string>:1, in delete(self, *args, **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:2897, in Canvas.delete(self, *args)
#    2895 def delete(self, *args):
#    2896     """Delete items identified by all tag or ids contained in ARGS."""
# -> 2897     self.tk.call((self._w, 'delete') + args)
#
# TclError: invalid command name ".!canvas"
